# %%
# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import torch
import torchvision
# from torchvision.models.detection.faster_rcnn import FastRCNNPredictor
# from torchvision.models.detection.mask_rcnn import MaskRCNNPredictor

def load_maskrcnn_model(save_path, device):
    """
    Load a trained PyTorch Mask R-CNN model

    Args:
        save_path: Path to the saved model
        device: Device to load the model to (cuda/cpu)
    Returns:
        model: The loaded model
    """
    # Initialize the model
    model = torchvision.models.detection.maskrcnn_resnet50_fpn(num_classes=33)

    # Load the state dict with proper file handling
    with open(save_path, 'rb') as f:
        state_dict = torch.load(f, map_location=device, weights_only=True)
        model.load_state_dict(state_dict)

    # Move model to device
    model = model.to(device)

    # Set to evaluation mode
    model.eval()

    return model


device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

maskrcnn_path="drive/MyDrive/training_data/quadrant_enumeration/dental_maskrcnn.pth"
markrcnn_model = load_maskrcnn_model(maskrcnn_path, device)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
# 100%|██████████| 97.8M/97.8M [00:00<00:00, 131MB/s]

# %% [markdown]
# # Modified UNet

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F


class ModifiedUNet(nn.Module):
    def __init__(self, in_channels=2, out_channels=33):  # in_channels=2 for image + bbox info
        super(ModifiedUNet, self).__init__()

        def conv_block(in_channels, out_channels):
            return nn.Sequential(
                nn.Conv2d(in_channels, out_channels, kernel_size=3, padding=1),
                nn.ReLU(inplace=True),
                nn.Conv2d(out_channels, out_channels, kernel_size=3, padding=1),
                nn.ReLU(inplace=True),
            )

        def up_block(in_channels, out_channels):
            return nn.ConvTranspose2d(in_channels, out_channels, kernel_size=2, stride=2)

        # Note: in_channels is now 2 (grayscale image + bbox mask)
        self.encoder1 = conv_block(in_channels, 64)
        self.encoder2 = conv_block(64, 128)
        self.encoder3 = conv_block(128, 256)
        self.encoder4 = conv_block(256, 512)

        self.pool = nn.MaxPool2d(kernel_size=2, stride=2)

        self.bottleneck = conv_block(512, 1024)

        self.upconv4 = up_block(1024, 512)
        self.decoder4 = conv_block(1024, 512)
        self.upconv3 = up_block(512, 256)
        self.decoder3 = conv_block(512, 256)
        self.upconv2 = up_block(256, 128)
        self.decoder2 = conv_block(256, 128)
        self.upconv1 = up_block(128, 64)
        self.decoder1 = conv_block(128, 64)

        self.final_conv = nn.Conv2d(64, out_channels, kernel_size=1)

    def forward(self, x):  # x is now the concatenated input
        enc1 = self.encoder1(x)
        enc2 = self.encoder2(self.pool(enc1))
        enc3 = self.encoder3(self.pool(enc2))
        enc4 = self.encoder4(self.pool(enc3))

        bottleneck = self.bottleneck(self.pool(enc4))

        dec4 = self.upconv4(bottleneck)
        dec4 = self.decoder4(torch.cat((dec4, enc4), dim=1))
        dec3 = self.upconv3(dec4)
        dec3 = self.decoder3(torch.cat((dec3, enc3), dim=1))
        dec2 = self.upconv2(dec3)
        dec2 = self.decoder2(torch.cat((dec2, enc2), dim=1))
        dec1 = self.upconv1(dec2)
        dec1 = self.decoder1(torch.cat((dec1, enc1), dim=1))

        return self.final_conv(dec1)





class ImprovedHybridSegmentation:
    def predict(self, image, confidence_threshold=0.5):
        """
        Improved hybrid segmentation using bbox information directly in U-Net
        """
        # 1. Get Mask R-CNN predictions
        maskrcnn_pred = self.maskrcnn([image])[0]

        # 2. Create bbox channel
        bbox_mask = torch.zeros((1, 1, image.shape[2], image.shape[3]),
                              device=self.device)

        # Fill bbox_mask with tooth index values in box regions
        for box, label in zip(maskrcnn_pred['boxes'], maskrcnn_pred['labels']):
            x1, y1, x2, y2 = map(int, box.cpu().numpy())
            bbox_mask[:, :, y1:y2, x1:x2] = label.item()

        # 3. Feed both image and bbox information to modified U-Net
        unet_pred = self.modified_unet(image, bbox_mask)

        return {
            'masks': unet_pred,
            'boxes': maskrcnn_pred['boxes'],
            'labels': maskrcnn_pred['labels'],
            'scores': maskrcnn_pred['scores']
        }

# %%
class DiceLoss(nn.Module):
    def __init__(self, weights=None):
        """
        DiceLoss with optional class weights.

        Args:
            weights (torch.Tensor): Weights for each class. Shape: (num_classes,)
        """
        super(DiceLoss, self).__init__()
        self.weights = weights

    def forward(self, pred, target):
        pred = torch.softmax(pred, dim=1)  # Class probabilities
        target = F.one_hot(target, num_classes=33).permute(0, 3, 1, 2).float()  # One-hot encode target

        intersection = (pred * target).sum(dim=(2, 3))  # Per class intersection
        union = pred.sum(dim=(2, 3)) + target.sum(dim=(2, 3))  # Per class union

        dice_score = 2.0 * intersection / (union + 1e-6)  # Per class Dice score

        # Apply weights
        if self.weights is not None:
            dice_score = dice_score * self.weights.view(1, -1)

        return 1.0 - dice_score.mean()  # Mean weighted Dice loss


def dice_metric(pred, target, num_classes=33):
    """
    Compute per-class Dice scores.
    """
    pred = torch.argmax(pred, dim=1)  # Shape: (batch_size, H, W)
    dice_scores = []

    for c in range(num_classes):
        pred_c = (pred == c).float()
        target_c = (target == c).float()

        intersection = (pred_c * target_c).sum()
        union = pred_c.sum() + target_c.sum()

        if union == 0:  # Avoid NaN for empty classes
            dice_scores.append(torch.tensor(1.0))  # Perfect score for empty classes
        else:
            dice_scores.append((2.0 * intersection) / (union + 1e-6))

    return dice_scores

# %%
import os
import json
from PIL import Image, ImageDraw
import numpy as np
from torch.utils.data import Dataset
from torchvision.transforms import functional as TF

class ModifiedToothSegmentationDataset(Dataset):
    def __init__(self, image_dir, mask_dir, coco_json, maskrcnn_model, device, transform=None):
        self.image_dir = image_dir
        self.mask_dir = mask_dir
        self.transform = transform
        self.maskrcnn_model = maskrcnn_model
        self.device = device

        with open(coco_json, "r") as f:
            coco_data = json.load(f)

        self.image_info = {img["id"]: img for img in coco_data["images"]}
        self.image_annotations = {img_id: [] for img_id in self.image_info.keys()}
        for annotation in coco_data["annotations"]:
            self.image_annotations[annotation["image_id"]].append(annotation)

        self.image_ids = list(self.image_info.keys())
        print(f"Dataset initialized with {len(self.image_ids)} images.")

    def __getitem__(self, index):
        image_id = self.image_ids[index]
        image_name = self.image_info[image_id]["file_name"]
        image_path = os.path.join(self.image_dir, image_name)

        # Load image
        image = Image.open(image_path).convert("L")  # Grayscale
        original_size = image.size

        # Create segmentation mask
        mask = Image.new("L", original_size, 0)
        draw = ImageDraw.Draw(mask)
        for annotation in self.image_annotations[image_id]:
            points = np.array(annotation["segmentation"]).reshape(-1, 2)
            draw.polygon([tuple(p) for p in points], fill=annotation["category_id"]+1)

        # Get Mask R-CNN predictions on original size image
        with torch.no_grad():
            # Convert to tensor without resizing and without adding batch dimension
            image_tensor = TF.to_tensor(Image.open(image_path).convert("L")).to(self.device)  # Shape: [1, H, W]
            maskrcnn_pred = self.maskrcnn_model([image_tensor])[0]  # Pass as list of tensors

        # Create bbox mask at original size
        bbox_mask = torch.zeros((1, *original_size[::-1]), device=self.device)
        for box, label in zip(maskrcnn_pred['boxes'], maskrcnn_pred['labels']):
            x1, y1, x2, y2 = map(int, box.cpu().numpy())
            bbox_mask[:, y1:y2, x1:x2] = label.item()

        # Apply transforms to image and mask
        if self.transform:
            image, mask = self.transform(image, mask)

        # Resize bbox_mask to match transformed image size
        bbox_mask = F.interpolate(bbox_mask.unsqueeze(0), size=(256, 256),
                                mode='nearest').squeeze(0)

        return image, bbox_mask.cpu(), mask

    def __len__(self):
        return len(self.image_ids)


from torch.utils.data import DataLoader
from torch.optim import Adam
from torch.nn import CrossEntropyLoss

def train_modified_unet(model, train_loader, val_loader, epochs, device, weights):
    model = model.to(device)
    optimizer = Adam(model.parameters(), lr=1e-3)

    if weights is not None:
        weights = weights.to(device)
        criterion = CrossEntropyLoss(weight=weights)
    else:
        criterion = CrossEntropyLoss()

    for epoch in range(epochs):
        model.train()
        train_loss = 0.0
        for images, bbox_masks, masks in train_loader:
            images = images.to(device)
            bbox_masks = bbox_masks.to(device)
            masks = masks.to(device)

            optimizer.zero_grad()
            # Concatenate image and bbox information
            inputs = torch.cat([images, bbox_masks], dim=1)
            outputs = model(inputs)
            loss = criterion(outputs, masks)
            loss.backward()
            optimizer.step()

            train_loss += loss.item()

        train_loss /= len(train_loader)
        print(f"Epoch {epoch + 1}/{epochs}, Train Loss: {train_loss:.4f}")

        # Validation step
        model.eval()
        with torch.no_grad():
            all_dice_scores = {c: [] for c in range(33)}
            for images, bbox_masks, masks in val_loader:
                images = images.to(device)
                bbox_masks = bbox_masks.to(device)
                masks = masks.to(device)

                inputs = torch.cat([images, bbox_masks], dim=1)
                outputs = model(inputs)
                per_class_dice = dice_metric(outputs, masks)
                for c, score in enumerate(per_class_dice):
                    all_dice_scores[c].append(score)

        mean_dice_scores = {c: sum(scores) / len(scores) for c, scores in all_dice_scores.items()}
        print(f"Epoch {epoch + 1}/{epochs}, Per-Class Dice Scores: {mean_dice_scores}")
        overall_dice = sum(mean_dice_scores.values()) / len(mean_dice_scores)
        print(f"Epoch {epoch + 1}/{epochs}, Overall Val Dice Score: {overall_dice:.4f}")

# %%
def transform(image, mask):
    image = TF.resize(image, (256, 256))
    mask = TF.resize(mask, (256, 256), interpolation=Image.NEAREST)
    image = TF.to_tensor(image)
    mask = torch.from_numpy(np.array(mask, dtype=np.int64))  # Convert to tensor
    return image, mask

# %%
# Paths
base_dir = "drive/MyDrive/training_data/quadrant_enumeration"
image_dir = os.path.join(base_dir, "xrays_2048_1024")
mask_dir = os.path.join(base_dir, "masks_teeth_2048_1024")
coco_json = os.path.join(base_dir, "coco_quadrant_enumeration_2048_1024.json")


num_classes = 33
background_proportion = 0.9
tooth_proportion = 0.1 / 32  # Each of the 32 classes share 10%

# Compute weights
weights = [1 / tooth_proportion] * 32  # Equal weight for all 32 classes
weights.append(1 / background_proportion)  # Weight for background class

# Normalize weights
weights = torch.tensor(weights, dtype=torch.float32)
weights /= weights.sum()  # Normalize so weights sum to ~1

# Print weights for reference
print("Class Weights:", weights)



# Usage:
batch_size = 4

# Initialize Mask R-CNN
maskrcnn_model = load_maskrcnn_model(maskrcnn_path, device)
maskrcnn_model.eval()  # Set to evaluation mode

# 3. Create dataset
dataset = ModifiedToothSegmentationDataset(
    image_dir=image_dir,
    mask_dir=mask_dir,
    coco_json=coco_json,
    maskrcnn_model=maskrcnn_model,
    device=device,
    transform=transform
)

train_size = int(0.8 * len(dataset))
val_size = len(dataset) - train_size
train_dataset, val_dataset = torch.utils.data.random_split(dataset, [train_size, val_size])

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

# Initialize modified U-Net (2 input channels for image + bbox mask)
model = ModifiedUNet(in_channels=2, out_channels=33)
# Out:
# Class Weights: tensor([0.0312, 0.0312, 0.0312, 0.0312, 0.0312, 0.0312, 0.0312, 0.0312, 0.0312,
#         0.0312, 0.0312, 0.0312, 0.0312, 0.0312, 0.0312, 0.0312, 0.0312, 0.0312,
#         0.0312, 0.0312, 0.0312, 0.0312, 0.0312, 0.0312, 0.0312, 0.0312, 0.0312,
#         0.0312, 0.0312, 0.0312, 0.0312, 0.0312, 0.0001])
# Dataset initialized with 634 images.

# %%
# Train
train_modified_unet(model, train_loader, val_loader, epochs=100, device=device, weights=weights)
# Out:
# Epoch 1/100, Train Loss: 1.0250
# Epoch 1/100, Per-Class Dice Scores: {0: tensor(0.9205, device='cuda:0'), 1: tensor(0., device='cuda:0'), 2: tensor(0., device='cuda:0'), 3: tensor(0., device='cuda:0'), 4: tensor(0., device='cuda:0'), 5: tensor(0., device='cuda:0'), 6: tensor(0., device='cuda:0'), 7: tensor(0., device='cuda:0'), 8: tensor(0., device='cuda:0'), 9: tensor(0., device='cuda:0'), 10: tensor(0., device='cuda:0'), 11: tensor(0., device='cuda:0'), 12: tensor(0., device='cuda:0'), 13: tensor(0., device='cuda:0'), 14: tensor(0., device='cuda:0'), 15: tensor(0., device='cuda:0'), 16: tensor(0., device='cuda:0'), 17: tensor(0., device='cuda:0'), 18: tensor(0., device='cuda:0'), 19: tensor(0., device='cuda:0'), 20: tensor(0., device='cuda:0'), 21: tensor(0., device='cuda:0'), 22: tensor(0., device='cuda:0'), 23: tensor(0., device='cuda:0'), 24: tensor(0., device='cuda:0'), 25: tensor(0., device='cuda:0'), 26: tensor(0., device='cuda:0'), 27: tensor(0., device='cuda:0'), 28: tensor(0., device='cuda:0'), 29: tensor(0., device='cuda:0'), 30: tensor(0.1706, device='cuda:0'), 31: tensor(0., device='cuda:0'), 32: tensor(0.0625, device='cuda:0')}
# Epoch 1/100, Overall Val Dice Score: 0.0350
# Epoch 2/100, Train Loss: 0.5591
# Epoch 2/100, Per-Class Dice Scores: {0: tensor(0.9261, device='cuda:0'), 1: tensor(0., device='cuda:0'), 2: tensor(0.1401, device='cuda:0'), 3: tensor(0.0642, device='cuda:0'), 4: tensor(0.2362, device='cuda:0'), 5: tensor(0., device='cuda:0'), 6: tensor(0.1384, device='cuda:0'), 7: tensor(0.2741, device='cuda:0'), 8: tensor(0., device='cuda:0'), 9: tensor(0., device='cuda:0'), 10: tensor(0., device='cuda:0'), 11: tensor(0., device='cuda:0'), 12: tensor(0., device='cuda:0'), 13: tensor(0.0027, device='cuda:0'), 14: tensor(0., device='cuda:0'), 15: tensor(0., device='cuda:0'), 16: tensor(0., device='cuda:0'), 17: tensor(0., device='cuda:0'), 18: tensor(0., device='cuda:0'), 19: tensor(0., device='cuda:0'), 20: tensor(0., device='cuda:0'), 21: tensor(0.0044, device='cuda:0'), 22: tensor(0.3125, device='cuda:0'), 23: tensor(0., device='cuda:0'), 24: tensor(0., device='cuda:0'), 25: tensor(0.3269, device='cuda:0'), 26: tensor(0., device='cuda:0'), 27: tensor(0., device='cuda:0'), 28: tensor(0., device='cuda:0'), 29: tensor(0.0214, device='cuda:0'), 30: tensor(0.0521, device='cuda:0'), 31: tensor(0.3533, device='cuda:0'), 32: tensor(0.0625, device='cuda:0')}
# Epoch 2/100, Overall Val Dice Score: 0.0883
# Epoch 3/100, Train Loss: 0.4793
# Epoch 3/100, Per-Class Dice Scores: {0: tensor(0.9652, device='cuda:0'), 1: tensor(0.1800, device='cuda:0'), 2: tensor(0.3096, device='cuda:0'), 3: tensor(0., device='cuda:0'), 4: tensor(0.0006, device='cuda:0'), 5: tensor(0.1785, device='cuda:0'), 6: tensor(0.4730, device='cuda:0'), 7: tensor(0.3552, device='cuda:0'), 8: tensor(0., device='cuda:0'), 9: tensor(0.0231, device='cuda:0'), 10: tensor(0.4075, device='cuda:0'), 11: tensor(0.3051, device='cuda:0'), 12: tensor(0.4373, device='cuda:0'), 13: tensor(0.0378, device='cuda:0'), 14: tensor(0.4841, device='cuda:0'), 15: tensor(0.3121, device='cuda:0'), 16: tensor(0., device='cuda:0'), 17: tensor(0.2542, device='cuda:0'), 18: tensor(0.0052, device='cuda:0'), 19: tensor(0.3549, device='cuda:0'), 20: tensor(0.2131, device='cuda:0'), 21: tensor(0.0231, device='cuda:0'), 22: tensor(0.4043, device='cuda:0'), 23: tensor(0.4771, device='cuda:0'), 24: tensor(0., device='cuda:0'), 25: tensor(0.0379, device='cuda:0'), 26: tensor(0.4165, device='cuda:0'), 27: tensor(0.2286, device='cuda:0'), 28: tensor(0.2673, device='cuda:0'), 29: tensor(0.2492, device='cuda:0'), 30: tensor(0.3941, device='cuda:0'), 31: tensor(0.1470, device='cuda:0'), 32: tensor(0.0625, device='cuda:0')}
# Epoch 3/100, Overall Val Dice Score: 0.2426
# Epoch 4/100, Train Loss: 0.4107
# Epoch 4/100, Per-Class Dice Scores: {0: tensor(0.9567, device='cuda:0'), 1: tensor(0.2029, device='cuda:0'), 2: tensor(0.3283, device='cuda:0'), 3: tensor(0.0113, device='cuda:0'), 4: tensor(0.3829, device='cuda:0'), 5: tensor(0.0042, device='cuda:0'), 6: tensor(0.5394, device='cuda:0'), 7: tensor(0.1889, device='cuda:0'), 8: tensor(0., device='cuda:0'), 9: tensor(0.3707, device='cuda:0'), 10: tensor(0.3519, device='cuda:0'), 11: tensor(0.4242, device='cuda:0'), 12: tensor(0.3257, device='cuda:0'), 13: tensor(0.3067, device='cuda:0'), 14: tensor(0.2203, device='cuda:0'), 15: tensor(0.4699, device='cuda:0'), 16: tensor(0., device='cuda:0'), 17: tensor(0.3302, device='cuda:0'), 18: tensor(0.4436, device='cuda:0'), 19: tensor(0.2645, device='cuda:0'), 20: tensor(0.2191, device='cuda:0'), 21: tensor(0.0332, device='cuda:0'), 22: tensor(0.1038, device='cuda:0'), 23: tensor(0.5097, device='cuda:0'), 24: tensor(0., device='cuda:0'), 25: tensor(0.4396, device='cuda:0'), 26: tensor(0.5138, device='cuda:0'), 27: tensor(0.5025, device='cuda:0'), 28: tensor(0.5052, device='cuda:0'), 29: tensor(0.4142, device='cuda:0'), 30: tensor(0.4741, device='cuda:0'), 31: tensor(0.5552, device='cuda:0'), 32: tensor(0.0625, device='cuda:0')}
# Epoch 4/100, Overall Val Dice Score: 0.3168
# Epoch 5/100, Train Loss: 0.3730
# Epoch 5/100, Per-Class Dice Scores: {0: tensor(0.9648, device='cuda:0'), 1: tensor(0.4318, device='cuda:0'), 2: tensor(0.4849, device='cuda:0'), 3: tensor(0.1267, device='cuda:0'), 4: tensor(0.4186, device='cuda:0'), 5: tensor(0.4260, device='cuda:0'), 6: tensor(0.4762, device='cuda:0'), 7: tensor(0.4486, device='cuda:0'), 8: tensor(0.4367, device='cuda:0'), 9: tensor(0.2526, device='cuda:0'), 10: tensor(0.1020, device='cuda:0'), 11: tensor(0.1864, device='cuda:0'), 12: tensor(0.1995, device='cuda:0'), 13: tensor(0.2913, device='cuda:0'), 14: tensor(0.3200, device='cuda:0'), 15: tensor(0.0031, device='cuda:0'), 16: tensor(0., device='cuda:0'), 17: tensor(0.3627, device='cuda:0'), 18: tensor(0.5125, device='cuda:0'), 19: tensor(0.3922, device='cuda:0'), 20: tensor(0.2818, device='cuda:0'), 21: tensor(0.4651, device='cuda:0'), 22: tensor(0.5188, device='cuda:0'), 23: tensor(0.5623, device='cuda:0'), 24: tensor(0., device='cuda:0'), 25: tensor(0.4983, device='cuda:0'), 26: tensor(0.5231, device='cuda:0'), 27: tensor(0.3688, device='cuda:0'), 28: tensor(0.5023, device='cuda:0'), 29: tensor(0.4769, device='cuda:0'), 30: tensor(0.5555, device='cuda:0'), 31: tensor(0.6126, device='cuda:0'), 32: tensor(0.0625, device='cuda:0')}
# Epoch 5/100, Overall Val Dice Score: 0.3717
# Epoch 6/100, Train Loss: 0.3335
# Epoch 6/100, Per-Class Dice Scores: {0: tensor(0.9567, device='cuda:0'), 1: tensor(0.4648, device='cuda:0'), 2: tensor(0.1008, device='cuda:0'), 3: tensor(0.4299, device='cuda:0'), 4: tensor(0.4286, device='cuda:0'), 5: tensor(0.4701, device='cuda:0'), 6: tensor(0.5658, device='cuda:0'), 7: tensor(0.4109, device='cuda:0'), 8: tensor(0.0756, device='cuda:0'), 9: tensor(0.3037, device='cuda:0'), 10: tensor(0.0211, device='cuda:0'), 11: tensor(0.2095, device='cuda:0'), 12: tensor(0.2732, device='cuda:0'), 13: tensor(0.2477, device='cuda:0'), 14: tensor(0.0876, device='cuda:0'), 15: tensor(0.3662, device='cuda:0'), 16: tensor(0., device='cuda:0'), 17: tensor(0.3752, device='cuda:0'), 18: tensor(0.1125, device='cuda:0'), 19: tensor(0.4961, device='cuda:0'), 20: tensor(0.4185, device='cuda:0'), 21: tensor(0.4113, device='cuda:0'), 22: tensor(0.4356, device='cuda:0'), 23: tensor(0., device='cuda:0'), 24: tensor(0., device='cuda:0'), 25: tensor(0.5081, device='cuda:0'), 26: tensor(0.4489, device='cuda:0'), 27: tensor(0.6157, device='cuda:0'), 28: tensor(0.2729, device='cuda:0'), 29: tensor(0.5423, device='cuda:0'), 30: tensor(0.6102, device='cuda:0'), 31: tensor(0.6365, device='cuda:0'), 32: tensor(0.0625, device='cuda:0')}
# Epoch 6/100, Overall Val Dice Score: 0.3442
# Epoch 7/100, Train Loss: 0.3189
# Epoch 7/100, Per-Class Dice Scores: {0: tensor(0.9664, device='cuda:0'), 1: tensor(0.4593, device='cuda:0'), 2: tensor(0.2781, device='cuda:0'), 3: tensor(0.5051, device='cuda:0'), 4: tensor(0.4928, device='cuda:0'), 5: tensor(0.5029, device='cuda:0'), 6: tensor(0.5854, device='cuda:0'), 7: tensor(0.5149, device='cuda:0'), 8: tensor(0.4562, device='cuda:0'), 9: tensor(0.5447, device='cuda:0'), 10: tensor(0.5466, device='cuda:0'), 11: tensor(0.4564, device='cuda:0'), 12: tensor(0.4959, device='cuda:0'), 13: tensor(0.4042, device='cuda:0'), 14: tensor(0.5924, device='cuda:0'), 15: tensor(0.5099, device='cuda:0'), 16: tensor(0., device='cuda:0'), 17: tensor(0.3260, device='cuda:0'), 18: tensor(0.4649, device='cuda:0'), 19: tensor(0.5737, device='cuda:0'), 20: tensor(0.3699, device='cuda:0'), 21: tensor(0.5040, device='cuda:0'), 22: tensor(0.5867, device='cuda:0'), 23: tensor(0.5547, device='cuda:0'), 24: tensor(0.5568, device='cuda:0'), 25: tensor(0.5387, device='cuda:0'), 26: tensor(0.5230, device='cuda:0'), 27: tensor(0.5555, device='cuda:0'), 28: tensor(0.4649, device='cuda:0'), 29: tensor(0.4262, device='cuda:0'), 30: tensor(0.5471, device='cuda:0'), 31: tensor(0.6154, device='cuda:0'), 32: tensor(0.0625, device='cuda:0')}
# Epoch 7/100, Overall Val Dice Score: 0.4843
# Epoch 8/100, Train Loss: 0.2943
# Epoch 8/100, Per-Class Dice Scores: {0: tensor(0.9584, device='cuda:0'), 1: tensor(0.6287, device='cuda:0'), 2: tensor(0.3678, device='cuda:0'), 3: tensor(0.4839, device='cuda:0'), 4: tensor(0.5691, device='cuda:0'), 5: tensor(0.4626, device='cuda:0'), 6: tensor(0.5783, device='cuda:0'), 7: tensor(0.5242, device='cuda:0'), 8: tensor(0.4341, device='cuda:0'), 9: tensor(0.6564, device='cuda:0'), 10: tensor(0.5299, device='cuda:0'), 11: tensor(0.4937, device='cuda:0'), 12: tensor(0.2469, device='cuda:0'), 13: tensor(0.3426, device='cuda:0'), 14: tensor(0.4861, device='cuda:0'), 15: tensor(0.4695, device='cuda:0'), 16: tensor(0.0009, device='cuda:0'), 17: tensor(0.4587, device='cuda:0'), 18: tensor(0.4462, device='cuda:0'), 19: tensor(0.5622, device='cuda:0'), 20: tensor(0.4449, device='cuda:0'), 21: tensor(0.3129, device='cuda:0'), 22: tensor(0.5877, device='cuda:0'), 23: tensor(0.0552, device='cuda:0'), 24: tensor(0.3931, device='cuda:0'), 25: tensor(0.5106, device='cuda:0'), 26: tensor(0.5140, device='cuda:0'), 27: tensor(0.5537, device='cuda:0'), 28: tensor(0.5211, device='cuda:0'), 29: tensor(0.5065, device='cuda:0'), 30: tensor(0.5704, device='cuda:0'), 31: tensor(0.6471, device='cuda:0'), 32: tensor(0.0625, device='cuda:0')}
# Epoch 8/100, Overall Val Dice Score: 0.4661
# Epoch 9/100, Train Loss: 0.2820
# Epoch 9/100, Per-Class Dice Scores: {0: tensor(0.9658, device='cuda:0'), 1: tensor(0.6747, device='cuda:0'), 2: tensor(0.5367, device='cuda:0'), 3: tensor(0.5195, device='cuda:0'), 4: tensor(0.5064, device='cuda:0'), 5: tensor(0.3891, device='cuda:0'), 6: tensor(0.5528, device='cuda:0'), 7: tensor(0.5625, device='cuda:0'), 8: tensor(0.4646, device='cuda:0'), 9: tensor(0.5775, device='cuda:0'), 10: tensor(0.2898, device='cuda:0'), 11: tensor(0.4056, device='cuda:0'), 12: tensor(0.4769, device='cuda:0'), 13: tensor(0.4267, device='cuda:0'), 14: tensor(0.5904, device='cuda:0'), 15: tensor(0.4702, device='cuda:0'), 16: tensor(0.5073, device='cuda:0'), 17: tensor(0.4559, device='cuda:0'), 18: tensor(0.4181, device='cuda:0'), 19: tensor(0.4570, device='cuda:0'), 20: tensor(0.4831, device='cuda:0'), 21: tensor(0.4127, device='cuda:0'), 22: tensor(0.5906, device='cuda:0'), 23: tensor(0.6405, device='cuda:0'), 24: tensor(0.3996, device='cuda:0'), 25: tensor(0.5778, device='cuda:0'), 26: tensor(0.5479, device='cuda:0'), 27: tensor(0.6361, device='cuda:0'), 28: tensor(0.5408, device='cuda:0'), 29: tensor(0.5943, device='cuda:0'), 30: tensor(0.5239, device='cuda:0'), 31: tensor(0.6575, device='cuda:0'), 32: tensor(0.0625, device='cuda:0')}
# Epoch 9/100, Overall Val Dice Score: 0.5126
# Epoch 10/100, Train Loss: 0.2758
# Epoch 10/100, Per-Class Dice Scores: {0: tensor(0.9643, device='cuda:0'), 1: tensor(0.6474, device='cuda:0'), 2: tensor(0.5477, device='cuda:0'), 3: tensor(0.5057, device='cuda:0'), 4: tensor(0.5122, device='cuda:0'), 5: tensor(0.5145, device='cuda:0'), 6: tensor(0.5590, device='cuda:0'), 7: tensor(0.5686, device='cuda:0'), 8: tensor(0.0974, device='cuda:0'), 9: tensor(0.6076, device='cuda:0'), 10: tensor(0.5513, device='cuda:0'), 11: tensor(0.4350, device='cuda:0'), 12: tensor(0.3901, device='cuda:0'), 13: tensor(0.4347, device='cuda:0'), 14: tensor(0.4765, device='cuda:0'), 15: tensor(0.3394, device='cuda:0'), 16: tensor(0.4504, device='cuda:0'), 17: tensor(0.5443, device='cuda:0'), 18: tensor(0.5157, device='cuda:0'), 19: tensor(0.5835, device='cuda:0'), 20: tensor(0.5558, device='cuda:0'), 21: tensor(0.5364, device='cuda:0'), 22: tensor(0.6058, device='cuda:0'), 23: tensor(0.6500, device='cuda:0'), 24: tensor(0.5927, device='cuda:0'), 25: tensor(0.5543, device='cuda:0'), 26: tensor(0.5521, device='cuda:0'), 27: tensor(0.6117, device='cuda:0'), 28: tensor(0.5574, device='cuda:0'), 29: tensor(0.5538, device='cuda:0'), 30: tensor(0.6201, device='cuda:0'), 31: tensor(0.6594, device='cuda:0'), 32: tensor(0.0625, device='cuda:0')}
# Epoch 10/100, Overall Val Dice Score: 0.5260
# Epoch 11/100, Train Loss: 0.2694
# Epoch 11/100, Per-Class Dice Scores: {0: tensor(0.9641, device='cuda:0'), 1: tensor(0.5882, device='cuda:0'), 2: tensor(0.5072, device='cuda:0'), 3: tensor(0.4636, device='cuda:0'), 4: tensor(0.5172, device='cuda:0'), 5: tensor(0.4930, device='cuda:0'), 6: tensor(0.5895, device='cuda:0'), 7: tensor(0.5594, device='cuda:0'), 8: tensor(0.4412, device='cuda:0'), 9: tensor(0.5476, device='cuda:0'), 10: tensor(0.5554, device='cuda:0'), 11: tensor(0.3895, device='cuda:0'), 12: tensor(0.5007, device='cuda:0'), 13: tensor(0.4761, device='cuda:0'), 14: tensor(0.6062, device='cuda:0'), 15: tensor(0.3997, device='cuda:0'), 16: tensor(0.5203, device='cuda:0'), 17: tensor(0.4199, device='cuda:0'), 18: tensor(0.5122, device='cuda:0'), 19: tensor(0.5762, device='cuda:0'), 20: tensor(0.5132, device='cuda:0'), 21: tensor(0.4762, device='cuda:0'), 22: tensor(0.5975, device='cuda:0'), 23: tensor(0.6025, device='cuda:0'), 24: tensor(0.0023, device='cuda:0'), 25: tensor(0.4663, device='cuda:0'), 26: tensor(0.4853, device='cuda:0'), 27: tensor(0.4928, device='cuda:0'), 28: tensor(0.3916, device='cuda:0'), 29: tensor(0.4075, device='cuda:0'), 30: tensor(0.5923, device='cuda:0'), 31: tensor(0.6290, device='cuda:0'), 32: tensor(0.0625, device='cuda:0')}
# Epoch 11/100, Overall Val Dice Score: 0.4953
# Epoch 12/100, Train Loss: 0.2673
# Epoch 12/100, Per-Class Dice Scores: {0: tensor(0.9673, device='cuda:0'), 1: tensor(0.5551, device='cuda:0'), 2: tensor(0.4921, device='cuda:0'), 3: tensor(0.5258, device='cuda:0'), 4: tensor(0.5252, device='cuda:0'), 5: tensor(0.5114, device='cuda:0'), 6: tensor(0.5989, device='cuda:0'), 7: tensor(0.5322, device='cuda:0'), 8: tensor(0.4946, device='cuda:0'), 9: tensor(0.5546, device='cuda:0'), 10: tensor(0.5663, device='cuda:0'), 11: tensor(0.4904, device='cuda:0'), 12: tensor(0.5080, device='cuda:0'), 13: tensor(0.5305, device='cuda:0'), 14: tensor(0.6325, device='cuda:0'), 15: tensor(0.5168, device='cuda:0'), 16: tensor(0.0008, device='cuda:0'), 17: tensor(0.5405, device='cuda:0'), 18: tensor(0.5765, device='cuda:0'), 19: tensor(0.6015, device='cuda:0'), 20: tensor(0.5556, device='cuda:0'), 21: tensor(0.5594, device='cuda:0'), 22: tensor(0.5916, device='cuda:0'), 23: tensor(0.6319, device='cuda:0'), 24: tensor(0.5774, device='cuda:0'), 25: tensor(0.5569, device='cuda:0'), 26: tensor(0.5810, device='cuda:0'), 27: tensor(0.6074, device='cuda:0'), 28: tensor(0.5995, device='cuda:0'), 29: tensor(0.5181, device='cuda:0'), 30: tensor(0.6221, device='cuda:0'), 31: tensor(0.6501, device='cuda:0'), 32: tensor(0.0625, device='cuda:0')}
# Epoch 12/100, Overall Val Dice Score: 0.5404
# Epoch 13/100, Train Loss: 0.2583
# Epoch 13/100, Per-Class Dice Scores: {0: tensor(0.9685, device='cuda:0'), 1: tensor(0.5456, device='cuda:0'), 2: tensor(0.5582, device='cuda:0'), 3: tensor(0.5369, device='cuda:0'), 4: tensor(0.5663, device='cuda:0'), 5: tensor(0.5029, device='cuda:0'), 6: tensor(0.6240, device='cuda:0'), 7: tensor(0.5336, device='cuda:0'), 8: tensor(0.5067, device='cuda:0'), 9: tensor(0.5538, device='cuda:0'), 10: tensor(0.4625, device='cuda:0'), 11: tensor(0.5363, device='cuda:0'), 12: tensor(0.5280, device='cuda:0'), 13: tensor(0.5001, device='cuda:0'), 14: tensor(0.5907, device='cuda:0'), 15: tensor(0.3777, device='cuda:0'), 16: tensor(0., device='cuda:0'), 17: tensor(0.4903, device='cuda:0'), 18: tensor(0.5008, device='cuda:0'), 19: tensor(0.6454, device='cuda:0'), 20: tensor(0.5993, device='cuda:0'), 21: tensor(0.5903, device='cuda:0'), 22: tensor(0.6133, device='cuda:0'), 23: tensor(0.5787, device='cuda:0'), 24: tensor(0.3178, device='cuda:0'), 25: tensor(0.5726, device='cuda:0'), 26: tensor(0.5353, device='cuda:0'), 27: tensor(0.6408, device='cuda:0'), 28: tensor(0.5904, device='cuda:0'), 29: tensor(0.5631, device='cuda:0'), 30: tensor(0.6360, device='cuda:0'), 31: tensor(0.6234, device='cuda:0'), 32: tensor(0.0625, device='cuda:0')}
# Epoch 13/100, Overall Val Dice Score: 0.5288
# Epoch 14/100, Train Loss: 0.2539
# Epoch 14/100, Per-Class Dice Scores: {0: tensor(0.9676, device='cuda:0'), 1: tensor(0.6437, device='cuda:0'), 2: tensor(0.5409, device='cuda:0'), 3: tensor(0.4660, device='cuda:0'), 4: tensor(0.4192, device='cuda:0'), 5: tensor(0.3926, device='cuda:0'), 6: tensor(0.4603, device='cuda:0'), 7: tensor(0.4897, device='cuda:0'), 8: tensor(0.4842, device='cuda:0'), 9: tensor(0.6565, device='cuda:0'), 10: tensor(0.6081, device='cuda:0'), 11: tensor(0.5400, device='cuda:0'), 12: tensor(0.5006, device='cuda:0'), 13: tensor(0.4831, device='cuda:0'), 14: tensor(0.6116, device='cuda:0'), 15: tensor(0.5932, device='cuda:0'), 16: tensor(0.5164, device='cuda:0'), 17: tensor(0.5540, device='cuda:0'), 18: tensor(0.6150, device='cuda:0'), 19: tensor(0.6391, device='cuda:0'), 20: tensor(0.5865, device='cuda:0'), 21: tensor(0.5990, device='cuda:0'), 22: tensor(0.6543, device='cuda:0'), 23: tensor(0.6814, device='cuda:0'), 24: tensor(0.6149, device='cuda:0'), 25: tensor(0.6183, device='cuda:0'), 26: tensor(0.5685, device='cuda:0'), 27: tensor(0.6337, device='cuda:0'), 28: tensor(0.5478, device='cuda:0'), 29: tensor(0.5037, device='cuda:0'), 30: tensor(0.5328, device='cuda:0'), 31: tensor(0.6235, device='cuda:0'), 32: tensor(0.0625, device='cuda:0')}
# Epoch 14/100, Overall Val Dice Score: 0.5578
# Epoch 15/100, Train Loss: 0.2441
# Epoch 15/100, Per-Class Dice Scores: {0: tensor(0.9681, device='cuda:0'), 1: tensor(0.7026, device='cuda:0'), 2: tensor(0.6069, device='cuda:0'), 3: tensor(0.5051, device='cuda:0'), 4: tensor(0.5474, device='cuda:0'), 5: tensor(0.5136, device='cuda:0'), 6: tensor(0.6203, device='cuda:0'), 7: tensor(0.5865, device='cuda:0'), 8: tensor(0.5053, device='cuda:0'), 9: tensor(0.6902, device='cuda:0'), 10: tensor(0.6269, device='cuda:0'), 11: tensor(0.5605, device='cuda:0'), 12: tensor(0.5180, device='cuda:0'), 13: tensor(0.5589, device='cuda:0'), 14: tensor(0.6452, device='cuda:0'), 15: tensor(0.5489, device='cuda:0'), 16: tensor(0.0132, device='cuda:0'), 17: tensor(0.6165, device='cuda:0'), 18: tensor(0.6243, device='cuda:0'), 19: tensor(0.6478, device='cuda:0'), 20: tensor(0.5837, device='cuda:0'), 21: tensor(0.5970, device='cuda:0'), 22: tensor(0.6600, device='cuda:0'), 23: tensor(0.6253, device='cuda:0'), 24: tensor(0.5191, device='cuda:0'), 25: tensor(0.6202, device='cuda:0'), 26: tensor(0.6130, device='cuda:0'), 27: tensor(0.6557, device='cuda:0'), 28: tensor(0.6298, device='cuda:0'), 29: tensor(0.6027, device='cuda:0'), 30: tensor(0.6350, device='cuda:0'), 31: tensor(0.6048, device='cuda:0'), 32: tensor(0.0625, device='cuda:0')}
# Epoch 15/100, Overall Val Dice Score: 0.5762
# Epoch 16/100, Train Loss: 0.2401
# Epoch 16/100, Per-Class Dice Scores: {0: tensor(0.9678, device='cuda:0'), 1: tensor(0.6810, device='cuda:0'), 2: tensor(0.6197, device='cuda:0'), 3: tensor(0.5159, device='cuda:0'), 4: tensor(0.5567, device='cuda:0'), 5: tensor(0.4880, device='cuda:0'), 6: tensor(0.5758, device='cuda:0'), 7: tensor(0.5737, device='cuda:0'), 8: tensor(0.4974, device='cuda:0'), 9: tensor(0.6946, device='cuda:0'), 10: tensor(0.6260, device='cuda:0'), 11: tensor(0.5484, device='cuda:0'), 12: tensor(0.5228, device='cuda:0'), 13: tensor(0.5772, device='cuda:0'), 14: tensor(0.6450, device='cuda:0'), 15: tensor(0.6145, device='cuda:0'), 16: tensor(0.5272, device='cuda:0'), 17: tensor(0.6066, device='cuda:0'), 18: tensor(0.5929, device='cuda:0'), 19: tensor(0.6520, device='cuda:0'), 20: tensor(0.5382, device='cuda:0'), 21: tensor(0.6018, device='cuda:0'), 22: tensor(0.6428, device='cuda:0'), 23: tensor(0.6555, device='cuda:0'), 24: tensor(0.6002, device='cuda:0'), 25: tensor(0.6253, device='cuda:0'), 26: tensor(0.5942, device='cuda:0'), 27: tensor(0.6240, device='cuda:0'), 28: tensor(0.5760, device='cuda:0'), 29: tensor(0.5498, device='cuda:0'), 30: tensor(0.5665, device='cuda:0'), 31: tensor(0.6397, device='cuda:0'), 32: tensor(0.0625, device='cuda:0')}
# Epoch 16/100, Overall Val Dice Score: 0.5867
# Epoch 17/100, Train Loss: 0.2405
# Epoch 17/100, Per-Class Dice Scores: {0: tensor(0.9686, device='cuda:0'), 1: tensor(0.6677, device='cuda:0'), 2: tensor(0.6404, device='cuda:0'), 3: tensor(0.5613, device='cuda:0'), 4: tensor(0.5577, device='cuda:0'), 5: tensor(0.5081, device='cuda:0'), 6: tensor(0.6124, device='cuda:0'), 7: tensor(0.6081, device='cuda:0'), 8: tensor(0.5156, device='cuda:0'), 9: tensor(0.5183, device='cuda:0'), 10: tensor(0.6052, device='cuda:0'), 11: tensor(0.5262, device='cuda:0'), 12: tensor(0.4265, device='cuda:0'), 13: tensor(0.5094, device='cuda:0'), 14: tensor(0.6364, device='cuda:0'), 15: tensor(0.5108, device='cuda:0'), 16: tensor(0.5379, device='cuda:0'), 17: tensor(0.5079, device='cuda:0'), 18: tensor(0.6204, device='cuda:0'), 19: tensor(0.6170, device='cuda:0'), 20: tensor(0.5595, device='cuda:0'), 21: tensor(0.5928, device='cuda:0'), 22: tensor(0.6600, device='cuda:0'), 23: tensor(0.6743, device='cuda:0'), 24: tensor(0.6177, device='cuda:0'), 25: tensor(0.5674, device='cuda:0'), 26: tensor(0.5836, device='cuda:0'), 27: tensor(0.6292, device='cuda:0'), 28: tensor(0.5956, device='cuda:0'), 29: tensor(0.5290, device='cuda:0'), 30: tensor(0.6080, device='cuda:0'), 31: tensor(0.6243, device='cuda:0'), 32: tensor(0.0625, device='cuda:0')}
# Epoch 17/100, Overall Val Dice Score: 0.5745
# Epoch 18/100, Train Loss: 0.2302
# Epoch 18/100, Per-Class Dice Scores: {0: tensor(0.9675, device='cuda:0'), 1: tensor(0.7008, device='cuda:0'), 2: tensor(0.6255, device='cuda:0'), 3: tensor(0.5515, device='cuda:0'), 4: tensor(0.5172, device='cuda:0'), 5: tensor(0.4999, device='cuda:0'), 6: tensor(0.6029, device='cuda:0'), 7: tensor(0.6049, device='cuda:0'), 8: tensor(0.5248, device='cuda:0'), 9: tensor(0.6598, device='cuda:0'), 10: tensor(0.6120, device='cuda:0'), 11: tensor(0.4956, device='cuda:0'), 12: tensor(0.5489, device='cuda:0'), 13: tensor(0.5562, device='cuda:0'), 14: tensor(0.6528, device='cuda:0'), 15: tensor(0.5908, device='cuda:0'), 16: tensor(0.4989, device='cuda:0'), 17: tensor(0.5909, device='cuda:0'), 18: tensor(0.5904, device='cuda:0'), 19: tensor(0.6263, device='cuda:0'), 20: tensor(0.5521, device='cuda:0'), 21: tensor(0.5502, device='cuda:0'), 22: tensor(0.6069, device='cuda:0'), 23: tensor(0.6949, device='cuda:0'), 24: tensor(0.6466, device='cuda:0'), 25: tensor(0.6164, device='cuda:0'), 26: tensor(0.6061, device='cuda:0'), 27: tensor(0.6440, device='cuda:0'), 28: tensor(0.5719, device='cuda:0'), 29: tensor(0.5277, device='cuda:0'), 30: tensor(0.5396, device='cuda:0'), 31: tensor(0.6651, device='cuda:0'), 32: tensor(0.0625, device='cuda:0')}
# Epoch 18/100, Overall Val Dice Score: 0.5849
# Epoch 19/100, Train Loss: 0.2277
# Epoch 19/100, Per-Class Dice Scores: {0: tensor(0.9676, device='cuda:0'), 1: tensor(0.5809, device='cuda:0'), 2: tensor(0.4321, device='cuda:0'), 3: tensor(0.4753, device='cuda:0'), 4: tensor(0.5030, device='cuda:0'), 5: tensor(0.5077, device='cuda:0'), 6: tensor(0.6092, device='cuda:0'), 7: tensor(0.5948, device='cuda:0'), 8: tensor(0.4859, device='cuda:0'), 9: tensor(0.5705, device='cuda:0'), 10: tensor(0.5719, device='cuda:0'), 11: tensor(0.5168, device='cuda:0'), 12: tensor(0.5211, device='cuda:0'), 13: tensor(0.5080, device='cuda:0'), 14: tensor(0.6317, device='cuda:0'), 15: tensor(0.5452, device='cuda:0'), 16: tensor(0.2311, device='cuda:0'), 17: tensor(0.5574, device='cuda:0'), 18: tensor(0.5979, device='cuda:0'), 19: tensor(0.6379, device='cuda:0'), 20: tensor(0.5938, device='cuda:0'), 21: tensor(0.6171, device='cuda:0'), 22: tensor(0.6768, device='cuda:0'), 23: tensor(0.6908, device='cuda:0'), 24: tensor(0.6660, device='cuda:0'), 25: tensor(0.5369, device='cuda:0'), 26: tensor(0.5053, device='cuda:0'), 27: tensor(0.6001, device='cuda:0'), 28: tensor(0.6077, device='cuda:0'), 29: tensor(0.5657, device='cuda:0'), 30: tensor(0.5816, device='cuda:0'), 31: tensor(0.6563, device='cuda:0'), 32: tensor(0.0625, device='cuda:0')}
# Epoch 19/100, Overall Val Dice Score: 0.5578
# Epoch 20/100, Train Loss: 0.2234
# Epoch 20/100, Per-Class Dice Scores: {0: tensor(0.9694, device='cuda:0'), 1: tensor(0.6806, device='cuda:0'), 2: tensor(0.5529, device='cuda:0'), 3: tensor(0.5255, device='cuda:0'), 4: tensor(0.5023, device='cuda:0'), 5: tensor(0.5344, device='cuda:0'), 6: tensor(0.6278, device='cuda:0'), 7: tensor(0.5670, device='cuda:0'), 8: tensor(0.5052, device='cuda:0'), 9: tensor(0.6761, device='cuda:0'), 10: tensor(0.6271, device='cuda:0'), 11: tensor(0.5620, device='cuda:0'), 12: tensor(0.5374, device='cuda:0'), 13: tensor(0.5579, device='cuda:0'), 14: tensor(0.6406, device='cuda:0'), 15: tensor(0.5962, device='cuda:0'), 16: tensor(0.4214, device='cuda:0'), 17: tensor(0.5605, device='cuda:0'), 18: tensor(0.6303, device='cuda:0'), 19: tensor(0.6749, device='cuda:0'), 20: tensor(0.6092, device='cuda:0'), 21: tensor(0.5997, device='cuda:0'), 22: tensor(0.6577, device='cuda:0'), 23: tensor(0.6901, device='cuda:0'), 24: tensor(0.6457, device='cuda:0'), 25: tensor(0.6001, device='cuda:0'), 26: tensor(0.5924, device='cuda:0'), 27: tensor(0.6303, device='cuda:0'), 28: tensor(0.6230, device='cuda:0'), 29: tensor(0.5942, device='cuda:0'), 30: tensor(0.6361, device='cuda:0'), 31: tensor(0.6287, device='cuda:0'), 32: tensor(0.0625, device='cuda:0')}
# Epoch 20/100, Overall Val Dice Score: 0.5915
# Epoch 21/100, Train Loss: 0.2244
# Epoch 21/100, Per-Class Dice Scores: {0: tensor(0.9689, device='cuda:0'), 1: tensor(0.7150, device='cuda:0'), 2: tensor(0.6195, device='cuda:0'), 3: tensor(0.5784, device='cuda:0'), 4: tensor(0.5399, device='cuda:0'), 5: tensor(0.5210, device='cuda:0'), 6: tensor(0.6232, device='cuda:0'), 7: tensor(0.5960, device='cuda:0'), 8: tensor(0.4801, device='cuda:0'), 9: tensor(0.6796, device='cuda:0'), 10: tensor(0.6244, device='cuda:0'), 11: tensor(0.5203, device='cuda:0'), 12: tensor(0.4910, device='cuda:0'), 13: tensor(0.5532, device='cuda:0'), 14: tensor(0.6520, device='cuda:0'), 15: tensor(0.5678, device='cuda:0'), 16: tensor(0.4875, device='cuda:0'), 17: tensor(0.5681, device='cuda:0'), 18: tensor(0.5857, device='cuda:0'), 19: tensor(0.6087, device='cuda:0'), 20: tensor(0.6180, device='cuda:0'), 21: tensor(0.6334, device='cuda:0'), 22: tensor(0.6801, device='cuda:0'), 23: tensor(0.6849, device='cuda:0'), 24: tensor(0.5353, device='cuda:0'), 25: tensor(0.5991, device='cuda:0'), 26: tensor(0.6163, device='cuda:0'), 27: tensor(0.6538, device='cuda:0'), 28: tensor(0.6229, device='cuda:0'), 29: tensor(0.6085, device='cuda:0'), 30: tensor(0.6318, device='cuda:0'), 31: tensor(0.6723, device='cuda:0'), 32: tensor(0.0625, device='cuda:0')}
# Epoch 21/100, Overall Val Dice Score: 0.5939
# Epoch 22/100, Train Loss: 0.2172
# Epoch 22/100, Per-Class Dice Scores: {0: tensor(0.9685, device='cuda:0'), 1: tensor(0.6701, device='cuda:0'), 2: tensor(0.6365, device='cuda:0'), 3: tensor(0.5186, device='cuda:0'), 4: tensor(0.4845, device='cuda:0'), 5: tensor(0.5041, device='cuda:0'), 6: tensor(0.5882, device='cuda:0'), 7: tensor(0.5391, device='cuda:0'), 8: tensor(0.5448, device='cuda:0'), 9: tensor(0.5983, device='cuda:0'), 10: tensor(0.6044, device='cuda:0'), 11: tensor(0.5554, device='cuda:0'), 12: tensor(0.4999, device='cuda:0'), 13: tensor(0.5599, device='cuda:0'), 14: tensor(0.6258, device='cuda:0'), 15: tensor(0.6390, device='cuda:0'), 16: tensor(0.5398, device='cuda:0'), 17: tensor(0.6175, device='cuda:0'), 18: tensor(0.6133, device='cuda:0'), 19: tensor(0.6654, device='cuda:0'), 20: tensor(0.6300, device='cuda:0'), 21: tensor(0.6184, device='cuda:0'), 22: tensor(0.6708, device='cuda:0'), 23: tensor(0.7041, device='cuda:0'), 24: tensor(0.6483, device='cuda:0'), 25: tensor(0.6183, device='cuda:0'), 26: tensor(0.6167, device='cuda:0'), 27: tensor(0.6567, device='cuda:0'), 28: tensor(0.6312, device='cuda:0'), 29: tensor(0.5999, device='cuda:0'), 30: tensor(0.6220, device='cuda:0'), 31: tensor(0.5980, device='cuda:0'), 32: tensor(0.0625, device='cuda:0')}
# Epoch 22/100, Overall Val Dice Score: 0.5955
# Epoch 23/100, Train Loss: 0.2142
# Epoch 23/100, Per-Class Dice Scores: {0: tensor(0.9686, device='cuda:0'), 1: tensor(0.6500, device='cuda:0'), 2: tensor(0.5547, device='cuda:0'), 3: tensor(0.5171, device='cuda:0'), 4: tensor(0.4669, device='cuda:0'), 5: tensor(0.3933, device='cuda:0'), 6: tensor(0.5771, device='cuda:0'), 7: tensor(0.5763, device='cuda:0'), 8: tensor(0.5076, device='cuda:0'), 9: tensor(0.6759, device='cuda:0'), 10: tensor(0.6641, device='cuda:0'), 11: tensor(0.4805, device='cuda:0'), 12: tensor(0.4728, device='cuda:0'), 13: tensor(0.5466, device='cuda:0'), 14: tensor(0.6064, device='cuda:0'), 15: tensor(0.6370, device='cuda:0'), 16: tensor(0.5814, device='cuda:0'), 17: tensor(0.6160, device='cuda:0'), 18: tensor(0.6141, device='cuda:0'), 19: tensor(0.6520, device='cuda:0'), 20: tensor(0.6254, device='cuda:0'), 21: tensor(0.6536, device='cuda:0'), 22: tensor(0.6925, device='cuda:0'), 23: tensor(0.7128, device='cuda:0'), 24: tensor(0.6808, device='cuda:0'), 25: tensor(0.5658, device='cuda:0'), 26: tensor(0.5914, device='cuda:0'), 27: tensor(0.6032, device='cuda:0'), 28: tensor(0.5461, device='cuda:0'), 29: tensor(0.4988, device='cuda:0'), 30: tensor(0.5578, device='cuda:0'), 31: tensor(0.6357, device='cuda:0'), 32: tensor(0.0625, device='cuda:0')}
# Epoch 23/100, Overall Val Dice Score: 0.5814
# Epoch 24/100, Train Loss: 0.2153
# Epoch 24/100, Per-Class Dice Scores: {0: tensor(0.9682, device='cuda:0'), 1: tensor(0.6683, device='cuda:0'), 2: tensor(0.6382, device='cuda:0'), 3: tensor(0.5971, device='cuda:0'), 4: tensor(0.5842, device='cuda:0'), 5: tensor(0.5346, device='cuda:0'), 6: tensor(0.6020, device='cuda:0'), 7: tensor(0.5574, device='cuda:0'), 8: tensor(0.3903, device='cuda:0'), 9: tensor(0.6220, device='cuda:0'), 10: tensor(0.5814, device='cuda:0'), 11: tensor(0.5418, device='cuda:0'), 12: tensor(0.5094, device='cuda:0'), 13: tensor(0.5565, device='cuda:0'), 14: tensor(0.6665, device='cuda:0'), 15: tensor(0.6367, device='cuda:0'), 16: tensor(0.4746, device='cuda:0'), 17: tensor(0.6358, device='cuda:0'), 18: tensor(0.6561, device='cuda:0'), 19: tensor(0.6878, device='cuda:0'), 20: tensor(0.6371, device='cuda:0'), 21: tensor(0.6389, device='cuda:0'), 22: tensor(0.6949, device='cuda:0'), 23: tensor(0.7160, device='cuda:0'), 24: tensor(0.6598, device='cuda:0'), 25: tensor(0.6303, device='cuda:0'), 26: tensor(0.6414, device='cuda:0'), 27: tensor(0.6774, device='cuda:0'), 28: tensor(0.6257, device='cuda:0'), 29: tensor(0.5745, device='cuda:0'), 30: tensor(0.6406, device='cuda:0'), 31: tensor(0.6131, device='cuda:0'), 32: tensor(0.0625, device='cuda:0')}
# Epoch 24/100, Overall Val Dice Score: 0.6037
# Epoch 25/100, Train Loss: 0.2045
# Epoch 25/100, Per-Class Dice Scores: {0: tensor(0.9695, device='cuda:0'), 1: tensor(0.7359, device='cuda:0'), 2: tensor(0.6337, device='cuda:0'), 3: tensor(0.6064, device='cuda:0'), 4: tensor(0.5463, device='cuda:0'), 5: tensor(0.5143, device='cuda:0'), 6: tensor(0.5901, device='cuda:0'), 7: tensor(0.6082, device='cuda:0'), 8: tensor(0.5356, device='cuda:0'), 9: tensor(0.6977, device='cuda:0'), 10: tensor(0.6478, device='cuda:0'), 11: tensor(0.5476, device='cuda:0'), 12: tensor(0.4775, device='cuda:0'), 13: tensor(0.5517, device='cuda:0'), 14: tensor(0.6692, device='cuda:0'), 15: tensor(0.6284, device='cuda:0'), 16: tensor(0.4014, device='cuda:0'), 17: tensor(0.5795, device='cuda:0'), 18: tensor(0.6380, device='cuda:0'), 19: tensor(0.6840, device='cuda:0'), 20: tensor(0.6394, device='cuda:0'), 21: tensor(0.6510, device='cuda:0'), 22: tensor(0.6749, device='cuda:0'), 23: tensor(0.7103, device='cuda:0'), 24: tensor(0.6701, device='cuda:0'), 25: tensor(0.5929, device='cuda:0'), 26: tensor(0.6139, device='cuda:0'), 27: tensor(0.6588, device='cuda:0'), 28: tensor(0.6310, device='cuda:0'), 29: tensor(0.6026, device='cuda:0'), 30: tensor(0.6513, device='cuda:0'), 31: tensor(0.6573, device='cuda:0'), 32: tensor(0.0625, device='cuda:0')}
# Epoch 25/100, Overall Val Dice Score: 0.6085
# Epoch 26/100, Train Loss: 0.2046
# Epoch 26/100, Per-Class Dice Scores: {0: tensor(0.9694, device='cuda:0'), 1: tensor(0.6891, device='cuda:0'), 2: tensor(0.6001, device='cuda:0'), 3: tensor(0.5428, device='cuda:0'), 4: tensor(0.5766, device='cuda:0'), 5: tensor(0.5481, device='cuda:0'), 6: tensor(0.6411, device='cuda:0'), 7: tensor(0.5699, device='cuda:0'), 8: tensor(0.5644, device='cuda:0'), 9: tensor(0.7056, device='cuda:0'), 10: tensor(0.6311, device='cuda:0'), 11: tensor(0.5202, device='cuda:0'), 12: tensor(0.4272, device='cuda:0'), 13: tensor(0.5264, device='cuda:0'), 14: tensor(0.6330, device='cuda:0'), 15: tensor(0.6267, device='cuda:0'), 16: tensor(0.5685, device='cuda:0'), 17: tensor(0.5939, device='cuda:0'), 18: tensor(0.6095, device='cuda:0'), 19: tensor(0.6493, device='cuda:0'), 20: tensor(0.6271, device='cuda:0'), 21: tensor(0.6465, device='cuda:0'), 22: tensor(0.6864, device='cuda:0'), 23: tensor(0.6934, device='cuda:0'), 24: tensor(0.6343, device='cuda:0'), 25: tensor(0.6116, device='cuda:0'), 26: tensor(0.5890, device='cuda:0'), 27: tensor(0.5837, device='cuda:0'), 28: tensor(0.5198, device='cuda:0'), 29: tensor(0.5089, device='cuda:0'), 30: tensor(0.6113, device='cuda:0'), 31: tensor(0.6251, device='cuda:0'), 32: tensor(0.0625, device='cuda:0')}
# Epoch 26/100, Overall Val Dice Score: 0.5937
# Epoch 27/100, Train Loss: 0.1998
# Epoch 27/100, Per-Class Dice Scores: {0: tensor(0.9683, device='cuda:0'), 1: tensor(0.7183, device='cuda:0'), 2: tensor(0.6458, device='cuda:0'), 3: tensor(0.5998, device='cuda:0'), 4: tensor(0.5847, device='cuda:0'), 5: tensor(0.5324, device='cuda:0'), 6: tensor(0.6143, device='cuda:0'), 7: tensor(0.5824, device='cuda:0'), 8: tensor(0.5205, device='cuda:0'), 9: tensor(0.7130, device='cuda:0'), 10: tensor(0.6652, device='cuda:0'), 11: tensor(0.5591, device='cuda:0'), 12: tensor(0.5743, device='cuda:0'), 13: tensor(0.5637, device='cuda:0'), 14: tensor(0.5894, device='cuda:0'), 15: tensor(0.5096, device='cuda:0'), 16: tensor(0.4804, device='cuda:0'), 17: tensor(0.6080, device='cuda:0'), 18: tensor(0.6478, device='cuda:0'), 19: tensor(0.6967, device='cuda:0'), 20: tensor(0.6469, device='cuda:0'), 21: tensor(0.6383, device='cuda:0'), 22: tensor(0.6839, device='cuda:0'), 23: tensor(0.6839, device='cuda:0'), 24: tensor(0.5614, device='cuda:0'), 25: tensor(0.6109, device='cuda:0'), 26: tensor(0.6009, device='cuda:0'), 27: tensor(0.6548, device='cuda:0'), 28: tensor(0.6257, device='cuda:0'), 29: tensor(0.5894, device='cuda:0'), 30: tensor(0.6350, device='cuda:0'), 31: tensor(0.6762, device='cuda:0'), 32: tensor(0.0625, device='cuda:0')}
# Epoch 27/100, Overall Val Dice Score: 0.6074
# Epoch 28/100, Train Loss: 0.1944
# Epoch 28/100, Per-Class Dice Scores: {0: tensor(0.9694, device='cuda:0'), 1: tensor(0.5523, device='cuda:0'), 2: tensor(0.5332, device='cuda:0'), 3: tensor(0.5431, device='cuda:0'), 4: tensor(0.5584, device='cuda:0'), 5: tensor(0.5607, device='cuda:0'), 6: tensor(0.6350, device='cuda:0'), 7: tensor(0.6202, device='cuda:0'), 8: tensor(0.5527, device='cuda:0'), 9: tensor(0.6254, device='cuda:0'), 10: tensor(0.5966, device='cuda:0'), 11: tensor(0.5944, device='cuda:0'), 12: tensor(0.5672, device='cuda:0'), 13: tensor(0.6043, device='cuda:0'), 14: tensor(0.6791, device='cuda:0'), 15: tensor(0.6395, device='cuda:0'), 16: tensor(0.4723, device='cuda:0'), 17: tensor(0.6510, device='cuda:0'), 18: tensor(0.6434, device='cuda:0'), 19: tensor(0.6811, device='cuda:0'), 20: tensor(0.6342, device='cuda:0'), 21: tensor(0.6472, device='cuda:0'), 22: tensor(0.6985, device='cuda:0'), 23: tensor(0.7115, device='cuda:0'), 24: tensor(0.6560, device='cuda:0'), 25: tensor(0.6300, device='cuda:0'), 26: tensor(0.6346, device='cuda:0'), 27: tensor(0.6511, device='cuda:0'), 28: tensor(0.6321, device='cuda:0'), 29: tensor(0.6114, device='cuda:0'), 30: tensor(0.6545, device='cuda:0'), 31: tensor(0.6760, device='cuda:0'), 32: tensor(0.0625, device='cuda:0')}
# Epoch 28/100, Overall Val Dice Score: 0.6115
# Epoch 29/100, Train Loss: 0.1926
# Epoch 29/100, Per-Class Dice Scores: {0: tensor(0.9665, device='cuda:0'), 1: tensor(0.7203, device='cuda:0'), 2: tensor(0.6641, device='cuda:0'), 3: tensor(0.5837, device='cuda:0'), 4: tensor(0.5735, device='cuda:0'), 5: tensor(0.5169, device='cuda:0'), 6: tensor(0.6304, device='cuda:0'), 7: tensor(0.5800, device='cuda:0'), 8: tensor(0.5209, device='cuda:0'), 9: tensor(0.6363, device='cuda:0'), 10: tensor(0.6526, device='cuda:0'), 11: tensor(0.5736, device='cuda:0'), 12: tensor(0.5706, device='cuda:0'), 13: tensor(0.5610, device='cuda:0'), 14: tensor(0.6569, device='cuda:0'), 15: tensor(0.6466, device='cuda:0'), 16: tensor(0.5858, device='cuda:0'), 17: tensor(0.6261, device='cuda:0'), 18: tensor(0.6323, device='cuda:0'), 19: tensor(0.6842, device='cuda:0'), 20: tensor(0.5984, device='cuda:0'), 21: tensor(0.6394, device='cuda:0'), 22: tensor(0.6607, device='cuda:0'), 23: tensor(0.7121, device='cuda:0'), 24: tensor(0.5657, device='cuda:0'), 25: tensor(0.6244, device='cuda:0'), 26: tensor(0.6252, device='cuda:0'), 27: tensor(0.6389, device='cuda:0'), 28: tensor(0.6197, device='cuda:0'), 29: tensor(0.5591, device='cuda:0'), 30: tensor(0.6069, device='cuda:0'), 31: tensor(0.5408, device='cuda:0'), 32: tensor(0.0625, device='cuda:0')}
# Epoch 29/100, Overall Val Dice Score: 0.6072
# Epoch 30/100, Train Loss: 0.1866
# Epoch 30/100, Per-Class Dice Scores: {0: tensor(0.9685, device='cuda:0'), 1: tensor(0.7018, device='cuda:0'), 2: tensor(0.6461, device='cuda:0'), 3: tensor(0.5961, device='cuda:0'), 4: tensor(0.5576, device='cuda:0'), 5: tensor(0.5213, device='cuda:0'), 6: tensor(0.6366, device='cuda:0'), 7: tensor(0.6220, device='cuda:0'), 8: tensor(0.5546, device='cuda:0'), 9: tensor(0.7020, device='cuda:0'), 10: tensor(0.6724, device='cuda:0'), 11: tensor(0.5888, device='cuda:0'), 12: tensor(0.5797, device='cuda:0'), 13: tensor(0.5949, device='cuda:0'), 14: tensor(0.6724, device='cuda:0'), 15: tensor(0.6431, device='cuda:0'), 16: tensor(0.5993, device='cuda:0'), 17: tensor(0.6250, device='cuda:0'), 18: tensor(0.6255, device='cuda:0'), 19: tensor(0.6826, device='cuda:0'), 20: tensor(0.6305, device='cuda:0'), 21: tensor(0.6260, device='cuda:0'), 22: tensor(0.6954, device='cuda:0'), 23: tensor(0.7260, device='cuda:0'), 24: tensor(0.6488, device='cuda:0'), 25: tensor(0.6257, device='cuda:0'), 26: tensor(0.6191, device='cuda:0'), 27: tensor(0.6546, device='cuda:0'), 28: tensor(0.6323, device='cuda:0'), 29: tensor(0.5496, device='cuda:0'), 30: tensor(0.6331, device='cuda:0'), 31: tensor(0.6839, device='cuda:0'), 32: tensor(0.0625, device='cuda:0')}
# Epoch 30/100, Overall Val Dice Score: 0.6236
# Epoch 31/100, Train Loss: 0.1863
# Epoch 31/100, Per-Class Dice Scores: {0: tensor(0.9681, device='cuda:0'), 1: tensor(0.7280, device='cuda:0'), 2: tensor(0.6515, device='cuda:0'), 3: tensor(0.5745, device='cuda:0'), 4: tensor(0.5377, device='cuda:0'), 5: tensor(0.5293, device='cuda:0'), 6: tensor(0.5881, device='cuda:0'), 7: tensor(0.5291, device='cuda:0'), 8: tensor(0.5112, device='cuda:0'), 9: tensor(0.7103, device='cuda:0'), 10: tensor(0.6181, device='cuda:0'), 11: tensor(0.5351, device='cuda:0'), 12: tensor(0.4539, device='cuda:0'), 13: tensor(0.4604, device='cuda:0'), 14: tensor(0.5678, device='cuda:0'), 15: tensor(0.4857, device='cuda:0'), 16: tensor(0.3834, device='cuda:0'), 17: tensor(0.6339, device='cuda:0'), 18: tensor(0.6495, device='cuda:0'), 19: tensor(0.6879, device='cuda:0'), 20: tensor(0.6592, device='cuda:0'), 21: tensor(0.6723, device='cuda:0'), 22: tensor(0.7024, device='cuda:0'), 23: tensor(0.7326, device='cuda:0'), 24: tensor(0.5793, device='cuda:0'), 25: tensor(0.6406, device='cuda:0'), 26: tensor(0.6301, device='cuda:0'), 27: tensor(0.6581, device='cuda:0'), 28: tensor(0.6335, device='cuda:0'), 29: tensor(0.5465, device='cuda:0'), 30: tensor(0.6410, device='cuda:0'), 31: tensor(0.6294, device='cuda:0'), 32: tensor(0.0625, device='cuda:0')}
# Epoch 31/100, Overall Val Dice Score: 0.5937
# Epoch 32/100, Train Loss: 0.1829
# Epoch 32/100, Per-Class Dice Scores: {0: tensor(0.9690, device='cuda:0'), 1: tensor(0.7233, device='cuda:0'), 2: tensor(0.6449, device='cuda:0'), 3: tensor(0.5825, device='cuda:0'), 4: tensor(0.5808, device='cuda:0'), 5: tensor(0.5265, device='cuda:0'), 6: tensor(0.6229, device='cuda:0'), 7: tensor(0.5856, device='cuda:0'), 8: tensor(0.5210, device='cuda:0'), 9: tensor(0.7150, device='cuda:0'), 10: tensor(0.6546, device='cuda:0'), 11: tensor(0.5735, device='cuda:0'), 12: tensor(0.5370, device='cuda:0'), 13: tensor(0.5877, device='cuda:0'), 14: tensor(0.6675, device='cuda:0'), 15: tensor(0.6460, device='cuda:0'), 16: tensor(0.5822, device='cuda:0'), 17: tensor(0.6067, device='cuda:0'), 18: tensor(0.5834, device='cuda:0'), 19: tensor(0.5958, device='cuda:0'), 20: tensor(0.5543, device='cuda:0'), 21: tensor(0.6219, device='cuda:0'), 22: tensor(0.6973, device='cuda:0'), 23: tensor(0.7310, device='cuda:0'), 24: tensor(0.6960, device='cuda:0'), 25: tensor(0.5899, device='cuda:0'), 26: tensor(0.5926, device='cuda:0'), 27: tensor(0.6383, device='cuda:0'), 28: tensor(0.6149, device='cuda:0'), 29: tensor(0.6242, device='cuda:0'), 30: tensor(0.6754, device='cuda:0'), 31: tensor(0.6796, device='cuda:0'), 32: tensor(0.0625, device='cuda:0')}
# Epoch 32/100, Overall Val Dice Score: 0.6147
# Epoch 33/100, Train Loss: 0.1798
# Epoch 33/100, Per-Class Dice Scores: {0: tensor(0.9698, device='cuda:0'), 1: tensor(0.7280, device='cuda:0'), 2: tensor(0.6507, device='cuda:0'), 3: tensor(0.5649, device='cuda:0'), 4: tensor(0.5739, device='cuda:0'), 5: tensor(0.4870, device='cuda:0'), 6: tensor(0.6410, device='cuda:0'), 7: tensor(0.6010, device='cuda:0'), 8: tensor(0.5470, device='cuda:0'), 9: tensor(0.7161, device='cuda:0'), 10: tensor(0.6519, device='cuda:0'), 11: tensor(0.5382, device='cuda:0'), 12: tensor(0.5767, device='cuda:0'), 13: tensor(0.5878, device='cuda:0'), 14: tensor(0.6817, device='cuda:0'), 15: tensor(0.6332, device='cuda:0'), 16: tensor(0.5772, device='cuda:0'), 17: tensor(0.6234, device='cuda:0'), 18: tensor(0.6409, device='cuda:0'), 19: tensor(0.6792, device='cuda:0'), 20: tensor(0.6447, device='cuda:0'), 21: tensor(0.6724, device='cuda:0'), 22: tensor(0.7072, device='cuda:0'), 23: tensor(0.7361, device='cuda:0'), 24: tensor(0.6976, device='cuda:0'), 25: tensor(0.6223, device='cuda:0'), 26: tensor(0.6333, device='cuda:0'), 27: tensor(0.6598, device='cuda:0'), 28: tensor(0.6115, device='cuda:0'), 29: tensor(0.6172, device='cuda:0'), 30: tensor(0.6816, device='cuda:0'), 31: tensor(0.6736, device='cuda:0'), 32: tensor(0.0625, device='cuda:0')}
# Epoch 33/100, Overall Val Dice Score: 0.6270
# Epoch 34/100, Train Loss: 0.1749
# Epoch 34/100, Per-Class Dice Scores: {0: tensor(0.9700, device='cuda:0'), 1: tensor(0.7438, device='cuda:0'), 2: tensor(0.6666, device='cuda:0'), 3: tensor(0.5935, device='cuda:0'), 4: tensor(0.5391, device='cuda:0'), 5: tensor(0.5077, device='cuda:0'), 6: tensor(0.5869, device='cuda:0'), 7: tensor(0.5938, device='cuda:0'), 8: tensor(0.5614, device='cuda:0'), 9: tensor(0.6973, device='cuda:0'), 10: tensor(0.6516, device='cuda:0'), 11: tensor(0.5983, device='cuda:0'), 12: tensor(0.5798, device='cuda:0'), 13: tensor(0.5938, device='cuda:0'), 14: tensor(0.6889, device='cuda:0'), 15: tensor(0.6553, device='cuda:0'), 16: tensor(0.6131, device='cuda:0'), 17: tensor(0.6272, device='cuda:0'), 18: tensor(0.6389, device='cuda:0'), 19: tensor(0.7024, device='cuda:0'), 20: tensor(0.6278, device='cuda:0'), 21: tensor(0.6512, device='cuda:0'), 22: tensor(0.6960, device='cuda:0'), 23: tensor(0.6938, device='cuda:0'), 24: tensor(0.6749, device='cuda:0'), 25: tensor(0.6326, device='cuda:0'), 26: tensor(0.6242, device='cuda:0'), 27: tensor(0.6616, device='cuda:0'), 28: tensor(0.6273, device='cuda:0'), 29: tensor(0.5988, device='cuda:0'), 30: tensor(0.6636, device='cuda:0'), 31: tensor(0.6414, device='cuda:0'), 32: tensor(0.0625, device='cuda:0')}
# Epoch 34/100, Overall Val Dice Score: 0.6262
# Epoch 35/100, Train Loss: 0.1692
# Epoch 35/100, Per-Class Dice Scores: {0: tensor(0.9675, device='cuda:0'), 1: tensor(0.7385, device='cuda:0'), 2: tensor(0.6557, device='cuda:0'), 3: tensor(0.5810, device='cuda:0'), 4: tensor(0.5189, device='cuda:0'), 5: tensor(0.5477, device='cuda:0'), 6: tensor(0.6225, device='cuda:0'), 7: tensor(0.6040, device='cuda:0'), 8: tensor(0.5422, device='cuda:0'), 9: tensor(0.7187, device='cuda:0'), 10: tensor(0.6422, device='cuda:0'), 11: tensor(0.5887, device='cuda:0'), 12: tensor(0.5431, device='cuda:0'), 13: tensor(0.5926, device='cuda:0'), 14: tensor(0.6448, device='cuda:0'), 15: tensor(0.5917, device='cuda:0'), 16: tensor(0.4667, device='cuda:0'), 17: tensor(0.6330, device='cuda:0'), 18: tensor(0.6634, device='cuda:0'), 19: tensor(0.6985, device='cuda:0'), 20: tensor(0.6766, device='cuda:0'), 21: tensor(0.7068, device='cuda:0'), 22: tensor(0.7126, device='cuda:0'), 23: tensor(0.7333, device='cuda:0'), 24: tensor(0.6971, device='cuda:0'), 25: tensor(0.6538, device='cuda:0'), 26: tensor(0.6252, device='cuda:0'), 27: tensor(0.6248, device='cuda:0'), 28: tensor(0.5674, device='cuda:0'), 29: tensor(0.5049, device='cuda:0'), 30: tensor(0.5915, device='cuda:0'), 31: tensor(0.6590, device='cuda:0'), 32: tensor(0.0625, device='cuda:0')}
# Epoch 35/100, Overall Val Dice Score: 0.6175
# Epoch 36/100, Train Loss: 0.1665
# Epoch 36/100, Per-Class Dice Scores: {0: tensor(0.9677, device='cuda:0'), 1: tensor(0.7343, device='cuda:0'), 2: tensor(0.6427, device='cuda:0'), 3: tensor(0.5974, device='cuda:0'), 4: tensor(0.5536, device='cuda:0'), 5: tensor(0.5672, device='cuda:0'), 6: tensor(0.6470, device='cuda:0'), 7: tensor(0.6151, device='cuda:0'), 8: tensor(0.5196, device='cuda:0'), 9: tensor(0.7201, device='cuda:0'), 10: tensor(0.6478, device='cuda:0'), 11: tensor(0.5547, device='cuda:0'), 12: tensor(0.5588, device='cuda:0'), 13: tensor(0.5819, device='cuda:0'), 14: tensor(0.6706, device='cuda:0'), 15: tensor(0.6742, device='cuda:0'), 16: tensor(0.6260, device='cuda:0'), 17: tensor(0.6153, device='cuda:0'), 18: tensor(0.6554, device='cuda:0'), 19: tensor(0.6821, device='cuda:0'), 20: tensor(0.6841, device='cuda:0'), 21: tensor(0.6810, device='cuda:0'), 22: tensor(0.7332, device='cuda:0'), 23: tensor(0.7374, device='cuda:0'), 24: tensor(0.6625, device='cuda:0'), 25: tensor(0.6376, device='cuda:0'), 26: tensor(0.6335, device='cuda:0'), 27: tensor(0.6621, device='cuda:0'), 28: tensor(0.6174, device='cuda:0'), 29: tensor(0.6292, device='cuda:0'), 30: tensor(0.6371, device='cuda:0'), 31: tensor(0.5922, device='cuda:0'), 32: tensor(0.0625, device='cuda:0')}
# Epoch 36/100, Overall Val Dice Score: 0.6303
# Epoch 37/100, Train Loss: 0.1627
# ...
# Epoch 62/100, Overall Val Dice Score: 0.6711
# Epoch 63/100, Train Loss: 0.0884
# Epoch 63/100, Per-Class Dice Scores: {0: tensor(0.9693, device='cuda:0'), 1: tensor(0.7390, device='cuda:0'), 2: tensor(0.6788, device='cuda:0'), 3: tensor(0.6155, device='cuda:0'), 4: tensor(0.5793, device='cuda:0'), 5: tensor(0.5527, device='cuda:0'), 6: tensor(0.6466, device='cuda:0'), 7: tensor(0.6266, device='cuda:0'), 8: tensor(0.5365, device='cuda:0'), 9: tensor(0.7397, device='cuda:0'), 10: tensor(0.7031, device='cuda:0'), 11: tensor(0.6459, device='cuda:0'), 12: tensor(0.5878, device='cuda:0'), 13: tensor(0.6028, device='cuda:0'), 14: tensor(0.6957, device='cuda:0'), 15: tensor(0.6711, device='cuda:0'), 16: tensor(0.6103, device='cuda:0'), 17: tensor(0.7031, device='cuda:0'), 18: tensor(0.7215, device='cuda:0'), 19: tensor(0.7519, device='cuda:0'), 20: tensor(0.7188, device='cuda:0'), 21: tensor(0.7200, device='cuda:0'), 22: tensor(0.7283, device='cuda:0'), 23: tensor(0.7575, device='cuda:0'), 24: tensor(0.7501, device='cuda:0'), 25: tensor(0.6942, device='cuda:0'), 26: tensor(0.6832, device='cuda:0'), 27: tensor(0.6959, device='cuda:0'), 28: tensor(0.6710, device='cuda:0'), 29: tensor(0.6654, device='cuda:0'), 30: tensor(0.7222, device='cuda:0'), 31: tensor(0.7159, device='cuda:0'), 32: tensor(0.0625, device='cuda:0')}
# Epoch 63/100, Overall Val Dice Score: 0.6655
# Epoch 64/100, Train Loss: 0.0876
# Epoch 64/100, Per-Class Dice Scores: {0: tensor(0.9697, device='cuda:0'), 1: tensor(0.7595, device='cuda:0'), 2: tensor(0.6990, device='cuda:0'), 3: tensor(0.6160, device='cuda:0'), 4: tensor(0.5876, device='cuda:0'), 5: tensor(0.5829, device='cuda:0'), 6: tensor(0.6707, device='cuda:0'), 7: tensor(0.6348, device='cuda:0'), 8: tensor(0.5500, device='cuda:0'), 9: tensor(0.7449, device='cuda:0'), 10: tensor(0.6862, device='cuda:0'), 11: tensor(0.6449, device='cuda:0'), 12: tensor(0.5768, device='cuda:0'), 13: tensor(0.5553, device='cuda:0'), 14: tensor(0.6918, device='cuda:0'), 15: tensor(0.6410, device='cuda:0'), 16: tensor(0.5119, device='cuda:0'), 17: tensor(0.7059, device='cuda:0'), 18: tensor(0.7178, device='cuda:0'), 19: tensor(0.7569, device='cuda:0'), 20: tensor(0.7229, device='cuda:0'), 21: tensor(0.7312, device='cuda:0'), 22: tensor(0.7474, device='cuda:0'), 23: tensor(0.7648, device='cuda:0'), 24: tensor(0.7271, device='cuda:0'), 25: tensor(0.6931, device='cuda:0'), 26: tensor(0.7008, device='cuda:0'), 27: tensor(0.7092, device='cuda:0'), 28: tensor(0.6688, device='cuda:0'), 29: tensor(0.6656, device='cuda:0'), 30: tensor(0.7334, device='cuda:0'), 31: tensor(0.7132, device='cuda:0'), 32: tensor(0.0625, device='cuda:0')}
# Epoch 64/100, Overall Val Dice Score: 0.6650
# Epoch 65/100, Train Loss: 0.0865
# Epoch 65/100, Per-Class Dice Scores: {0: tensor(0.9681, device='cuda:0'), 1: tensor(0.7183, device='cuda:0'), 2: tensor(0.6416, device='cuda:0'), 3: tensor(0.5805, device='cuda:0'), 4: tensor(0.5530, device='cuda:0'), 5: tensor(0.5197, device='cuda:0'), 6: tensor(0.6400, device='cuda:0'), 7: tensor(0.6389, device='cuda:0'), 8: tensor(0.5290, device='cuda:0'), 9: tensor(0.7350, device='cuda:0'), 10: tensor(0.6806, device='cuda:0'), 11: tensor(0.6375, device='cuda:0'), 12: tensor(0.6051, device='cuda:0'), 13: tensor(0.5971, device='cuda:0'), 14: tensor(0.6989, device='cuda:0'), 15: tensor(0.6336, device='cuda:0'), 16: tensor(0.4884, device='cuda:0'), 17: tensor(0.7138, device='cuda:0'), 18: tensor(0.7235, device='cuda:0'), 19: tensor(0.7552, device='cuda:0'), 20: tensor(0.7249, device='cuda:0'), 21: tensor(0.7291, device='cuda:0'), 22: tensor(0.7319, device='cuda:0'), 23: tensor(0.7437, device='cuda:0'), 24: tensor(0.6468, device='cuda:0'), 25: tensor(0.6927, device='cuda:0'), 26: tensor(0.6863, device='cuda:0'), 27: tensor(0.6786, device='cuda:0'), 28: tensor(0.6239, device='cuda:0'), 29: tensor(0.6355, device='cuda:0'), 30: tensor(0.7038, device='cuda:0'), 31: tensor(0.7211, device='cuda:0'), 32: tensor(0.0625, device='cuda:0')}
# Epoch 65/100, Overall Val Dice Score: 0.6497
# Epoch 66/100, Train Loss: 0.0900
# Epoch 66/100, Per-Class Dice Scores: {0: tensor(0.9700, device='cuda:0'), 1: tensor(0.7635, device='cuda:0'), 2: tensor(0.6978, device='cuda:0'), 3: tensor(0.6155, device='cuda:0'), 4: tensor(0.5888, device='cuda:0'), 5: tensor(0.5669, device='cuda:0'), 6: tensor(0.6579, device='cuda:0'), 7: tensor(0.6500, device='cuda:0'), 8: tensor(0.5347, device='cuda:0'), 9: tensor(0.7593, device='cuda:0'), 10: tensor(0.7256, device='cuda:0'), 11: tensor(0.6596, device='cuda:0'), 12: tensor(0.6014, device='cuda:0'), 13: tensor(0.5999, device='cuda:0'), 14: tensor(0.6917, device='cuda:0'), 15: tensor(0.6595, device='cuda:0'), 16: tensor(0.5513, device='cuda:0'), 17: tensor(0.6695, device='cuda:0'), 18: tensor(0.6965, device='cuda:0'), 19: tensor(0.7432, device='cuda:0'), 20: tensor(0.7145, device='cuda:0'), 21: tensor(0.7225, device='cuda:0'), 22: tensor(0.7244, device='cuda:0'), 23: tensor(0.7614, device='cuda:0'), 24: tensor(0.7511, device='cuda:0'), 25: tensor(0.6632, device='cuda:0'), 26: tensor(0.6813, device='cuda:0'), 27: tensor(0.6991, device='cuda:0'), 28: tensor(0.6613, device='cuda:0'), 29: tensor(0.6694, device='cuda:0'), 30: tensor(0.7191, device='cuda:0'), 31: tensor(0.7077, device='cuda:0'), 32: tensor(0.0625, device='cuda:0')}
# Epoch 66/100, Overall Val Dice Score: 0.6649
# Epoch 67/100, Train Loss: 0.0854
# Epoch 67/100, Per-Class Dice Scores: {0: tensor(0.9700, device='cuda:0'), 1: tensor(0.7517, device='cuda:0'), 2: tensor(0.6762, device='cuda:0'), 3: tensor(0.6178, device='cuda:0'), 4: tensor(0.5886, device='cuda:0'), 5: tensor(0.5723, device='cuda:0'), 6: tensor(0.6802, device='cuda:0'), 7: tensor(0.6536, device='cuda:0'), 8: tensor(0.5564, device='cuda:0'), 9: tensor(0.7403, device='cuda:0'), 10: tensor(0.6967, device='cuda:0'), 11: tensor(0.6378, device='cuda:0'), 12: tensor(0.5788, device='cuda:0'), 13: tensor(0.6009, device='cuda:0'), 14: tensor(0.7044, device='cuda:0'), 15: tensor(0.6659, device='cuda:0'), 16: tensor(0.5849, device='cuda:0'), 17: tensor(0.6879, device='cuda:0'), 18: tensor(0.7114, device='cuda:0'), 19: tensor(0.7491, device='cuda:0'), 20: tensor(0.7092, device='cuda:0'), 21: tensor(0.7294, device='cuda:0'), 22: tensor(0.7188, device='cuda:0'), 23: tensor(0.7525, device='cuda:0'), 24: tensor(0.7539, device='cuda:0'), 25: tensor(0.6688, device='cuda:0'), 26: tensor(0.6942, device='cuda:0'), 27: tensor(0.7189, device='cuda:0'), 28: tensor(0.6693, device='cuda:0'), 29: tensor(0.6636, device='cuda:0'), 30: tensor(0.7302, device='cuda:0'), 31: tensor(0.7357, device='cuda:0'), 32: tensor(0.0625, device='cuda:0')}
# Epoch 67/100, Overall Val Dice Score: 0.6676
# Epoch 68/100, Train Loss: 0.0881
# Epoch 68/100, Per-Class Dice Scores: {0: tensor(0.9698, device='cuda:0'), 1: tensor(0.7488, device='cuda:0'), 2: tensor(0.6943, device='cuda:0'), 3: tensor(0.6176, device='cuda:0'), 4: tensor(0.5978, device='cuda:0'), 5: tensor(0.5535, device='cuda:0'), 6: tensor(0.6706, device='cuda:0'), 7: tensor(0.6179, device='cuda:0'), 8: tensor(0.5413, device='cuda:0'), 9: tensor(0.7486, device='cuda:0'), 10: tensor(0.7064, device='cuda:0'), 11: tensor(0.6428, device='cuda:0'), 12: tensor(0.5927, device='cuda:0'), 13: tensor(0.5806, device='cuda:0'), 14: tensor(0.6841, device='cuda:0'), 15: tensor(0.6634, device='cuda:0'), 16: tensor(0.5482, device='cuda:0'), 17: tensor(0.7061, device='cuda:0'), 18: tensor(0.7204, device='cuda:0'), 19: tensor(0.7471, device='cuda:0'), 20: tensor(0.7174, device='cuda:0'), 21: tensor(0.7098, device='cuda:0'), 22: tensor(0.7262, device='cuda:0'), 23: tensor(0.7436, device='cuda:0'), 24: tensor(0.7216, device='cuda:0'), 25: tensor(0.6785, device='cuda:0'), 26: tensor(0.6896, device='cuda:0'), 27: tensor(0.7007, device='cuda:0'), 28: tensor(0.6779, device='cuda:0'), 29: tensor(0.6732, device='cuda:0'), 30: tensor(0.7218, device='cuda:0'), 31: tensor(0.7182, device='cuda:0'), 32: tensor(0.0625, device='cuda:0')}
# Epoch 68/100, Overall Val Dice Score: 0.6634
# Epoch 69/100, Train Loss: 0.0854
# Epoch 69/100, Per-Class Dice Scores: {0: tensor(0.9684, device='cuda:0'), 1: tensor(0.7464, device='cuda:0'), 2: tensor(0.6880, device='cuda:0'), 3: tensor(0.6151, device='cuda:0'), 4: tensor(0.5733, device='cuda:0'), 5: tensor(0.5840, device='cuda:0'), 6: tensor(0.6398, device='cuda:0'), 7: tensor(0.6484, device='cuda:0'), 8: tensor(0.5515, device='cuda:0'), 9: tensor(0.7298, device='cuda:0'), 10: tensor(0.7095, device='cuda:0'), 11: tensor(0.6575, device='cuda:0'), 12: tensor(0.6059, device='cuda:0'), 13: tensor(0.5910, device='cuda:0'), 14: tensor(0.6855, device='cuda:0'), 15: tensor(0.6707, device='cuda:0'), 16: tensor(0.5696, device='cuda:0'), 17: tensor(0.7093, device='cuda:0'), 18: tensor(0.7423, device='cuda:0'), 19: tensor(0.7603, device='cuda:0'), 20: tensor(0.7205, device='cuda:0'), 21: tensor(0.7235, device='cuda:0'), 22: tensor(0.7125, device='cuda:0'), 23: tensor(0.7442, device='cuda:0'), 24: tensor(0.7225, device='cuda:0'), 25: tensor(0.6846, device='cuda:0'), 26: tensor(0.6919, device='cuda:0'), 27: tensor(0.6828, device='cuda:0'), 28: tensor(0.6765, device='cuda:0'), 29: tensor(0.6451, device='cuda:0'), 30: tensor(0.7130, device='cuda:0'), 31: tensor(0.7287, device='cuda:0'), 32: tensor(0.0625, device='cuda:0')}
# Epoch 69/100, Overall Val Dice Score: 0.6653
# Epoch 70/100, Train Loss: 0.0811
# Epoch 70/100, Per-Class Dice Scores: {0: tensor(0.9695, device='cuda:0'), 1: tensor(0.7427, device='cuda:0'), 2: tensor(0.6843, device='cuda:0'), 3: tensor(0.5976, device='cuda:0'), 4: tensor(0.5920, device='cuda:0'), 5: tensor(0.5590, device='cuda:0'), 6: tensor(0.6652, device='cuda:0'), 7: tensor(0.6267, device='cuda:0'), 8: tensor(0.4734, device='cuda:0'), 9: tensor(0.7362, device='cuda:0'), 10: tensor(0.6940, device='cuda:0'), 11: tensor(0.6393, device='cuda:0'), 12: tensor(0.6057, device='cuda:0'), 13: tensor(0.5652, device='cuda:0'), 14: tensor(0.6393, device='cuda:0'), 15: tensor(0.6416, device='cuda:0'), 16: tensor(0.5437, device='cuda:0'), 17: tensor(0.7007, device='cuda:0'), 18: tensor(0.7297, device='cuda:0'), 19: tensor(0.7647, device='cuda:0'), 20: tensor(0.7188, device='cuda:0'), 21: tensor(0.7230, device='cuda:0'), 22: tensor(0.7302, device='cuda:0'), 23: tensor(0.7582, device='cuda:0'), 24: tensor(0.7375, device='cuda:0'), 25: tensor(0.6875, device='cuda:0'), 26: tensor(0.7037, device='cuda:0'), 27: tensor(0.7048, device='cuda:0'), 28: tensor(0.6756, device='cuda:0'), 29: tensor(0.6739, device='cuda:0'), 30: tensor(0.7358, device='cuda:0'), 31: tensor(0.7222, device='cuda:0'), 32: tensor(0.0625, device='cuda:0')}
# Epoch 70/100, Overall Val Dice Score: 0.6607
# Epoch 71/100, Train Loss: 0.0780
# Epoch 71/100, Per-Class Dice Scores: {0: tensor(0.9693, device='cuda:0'), 1: tensor(0.7641, device='cuda:0'), 2: tensor(0.6868, device='cuda:0'), 3: tensor(0.6060, device='cuda:0'), 4: tensor(0.5999, device='cuda:0'), 5: tensor(0.5764, device='cuda:0'), 6: tensor(0.6577, device='cuda:0'), 7: tensor(0.6586, device='cuda:0'), 8: tensor(0.5571, device='cuda:0'), 9: tensor(0.7553, device='cuda:0'), 10: tensor(0.7131, device='cuda:0'), 11: tensor(0.6639, device='cuda:0'), 12: tensor(0.6071, device='cuda:0'), 13: tensor(0.6243, device='cuda:0'), 14: tensor(0.7066, device='cuda:0'), 15: tensor(0.6418, device='cuda:0'), 16: tensor(0.5078, device='cuda:0'), 17: tensor(0.7039, device='cuda:0'), 18: tensor(0.7369, device='cuda:0'), 19: tensor(0.7629, device='cuda:0'), 20: tensor(0.7130, device='cuda:0'), 21: tensor(0.7239, device='cuda:0'), 22: tensor(0.7279, device='cuda:0'), 23: tensor(0.7609, device='cuda:0'), 24: tensor(0.7324, device='cuda:0'), 25: tensor(0.6944, device='cuda:0'), 26: tensor(0.7181, device='cuda:0'), 27: tensor(0.7055, device='cuda:0'), 28: tensor(0.6696, device='cuda:0'), 29: tensor(0.6715, device='cuda:0'), 30: tensor(0.7406, device='cuda:0'), 31: tensor(0.7297, device='cuda:0'), 32: tensor(0.0631, device='cuda:0')}
# Epoch 71/100, Overall Val Dice Score: 0.6712
# Epoch 72/100, Train Loss: 0.0758
# Epoch 72/100, Per-Class Dice Scores: {0: tensor(0.9696, device='cuda:0'), 1: tensor(0.7505, device='cuda:0'), 2: tensor(0.6906, device='cuda:0'), 3: tensor(0.6162, device='cuda:0'), 4: tensor(0.5799, device='cuda:0'), 5: tensor(0.5805, device='cuda:0'), 6: tensor(0.6670, device='cuda:0'), 7: tensor(0.6418, device='cuda:0'), 8: tensor(0.5426, device='cuda:0'), 9: tensor(0.7331, device='cuda:0'), 10: tensor(0.7071, device='cuda:0'), 11: tensor(0.6591, device='cuda:0'), 12: tensor(0.5838, device='cuda:0'), 13: tensor(0.5983, device='cuda:0'), 14: tensor(0.6821, device='cuda:0'), 15: tensor(0.6505, device='cuda:0'), 16: tensor(0.5684, device='cuda:0'), 17: tensor(0.7100, device='cuda:0'), 18: tensor(0.7308, device='cuda:0'), 19: tensor(0.7568, device='cuda:0'), 20: tensor(0.7187, device='cuda:0'), 21: tensor(0.7204, device='cuda:0'), 22: tensor(0.7357, device='cuda:0'), 23: tensor(0.7530, device='cuda:0'), 24: tensor(0.7379, device='cuda:0'), 25: tensor(0.6944, device='cuda:0'), 26: tensor(0.6938, device='cuda:0'), 27: tensor(0.7016, device='cuda:0'), 28: tensor(0.6676, device='cuda:0'), 29: tensor(0.6683, device='cuda:0'), 30: tensor(0.7319, device='cuda:0'), 31: tensor(0.7164, device='cuda:0'), 32: tensor(0.0630, device='cuda:0')}
# Epoch 72/100, Overall Val Dice Score: 0.6673
# Epoch 73/100, Train Loss: 0.0736
# Epoch 73/100, Per-Class Dice Scores: {0: tensor(0.9699, device='cuda:0'), 1: tensor(0.7664, device='cuda:0'), 2: tensor(0.6966, device='cuda:0'), 3: tensor(0.6141, device='cuda:0'), 4: tensor(0.5732, device='cuda:0'), 5: tensor(0.5687, device='cuda:0'), 6: tensor(0.6705, device='cuda:0'), 7: tensor(0.6531, device='cuda:0'), 8: tensor(0.5546, device='cuda:0'), 9: tensor(0.7504, device='cuda:0'), 10: tensor(0.7026, device='cuda:0'), 11: tensor(0.6535, device='cuda:0'), 12: tensor(0.6119, device='cuda:0'), 13: tensor(0.5955, device='cuda:0'), 14: tensor(0.7067, device='cuda:0'), 15: tensor(0.6696, device='cuda:0'), 16: tensor(0.5603, device='cuda:0'), 17: tensor(0.6988, device='cuda:0'), 18: tensor(0.7288, device='cuda:0'), 19: tensor(0.7512, device='cuda:0'), 20: tensor(0.7149, device='cuda:0'), 21: tensor(0.7117, device='cuda:0'), 22: tensor(0.7289, device='cuda:0'), 23: tensor(0.7493, device='cuda:0'), 24: tensor(0.7299, device='cuda:0'), 25: tensor(0.6952, device='cuda:0'), 26: tensor(0.6918, device='cuda:0'), 27: tensor(0.6818, device='cuda:0'), 28: tensor(0.6796, device='cuda:0'), 29: tensor(0.6765, device='cuda:0'), 30: tensor(0.7413, device='cuda:0'), 31: tensor(0.7155, device='cuda:0'), 32: tensor(0.0656, device='cuda:0')}
# Epoch 73/100, Overall Val Dice Score: 0.6690
# Epoch 74/100, Train Loss: 0.0718
# Epoch 74/100, Per-Class Dice Scores: {0: tensor(0.9690, device='cuda:0'), 1: tensor(0.7513, device='cuda:0'), 2: tensor(0.6845, device='cuda:0'), 3: tensor(0.6057, device='cuda:0'), 4: tensor(0.5852, device='cuda:0'), 5: tensor(0.5543, device='cuda:0'), 6: tensor(0.6638, device='cuda:0'), 7: tensor(0.6457, device='cuda:0'), 8: tensor(0.5187, device='cuda:0'), 9: tensor(0.7591, device='cuda:0'), 10: tensor(0.7189, device='cuda:0'), 11: tensor(0.6123, device='cuda:0'), 12: tensor(0.5930, device='cuda:0'), 13: tensor(0.6281, device='cuda:0'), 14: tensor(0.6973, device='cuda:0'), 15: tensor(0.6449, device='cuda:0'), 16: tensor(0.5691, device='cuda:0'), 17: tensor(0.7011, device='cuda:0'), 18: tensor(0.7171, device='cuda:0'), 19: tensor(0.7556, device='cuda:0'), 20: tensor(0.7120, device='cuda:0'), 21: tensor(0.7163, device='cuda:0'), 22: tensor(0.7336, device='cuda:0'), 23: tensor(0.7498, device='cuda:0'), 24: tensor(0.7277, device='cuda:0'), 25: tensor(0.6946, device='cuda:0'), 26: tensor(0.6965, device='cuda:0'), 27: tensor(0.7045, device='cuda:0'), 28: tensor(0.6740, device='cuda:0'), 29: tensor(0.6624, device='cuda:0'), 30: tensor(0.7184, device='cuda:0'), 31: tensor(0.7274, device='cuda:0'), 32: tensor(0.0676, device='cuda:0')}
# Epoch 74/100, Overall Val Dice Score: 0.6654

# %%
model.save('bbunet_maskrcnn.pth')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-7419e68a9921> in <cell line: 1>()
# ----> 1 model.save('bbunet_maskrcnn.pth')
#
# NameError: name 'model' is not defined
